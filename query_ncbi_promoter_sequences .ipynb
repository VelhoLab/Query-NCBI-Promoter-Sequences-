# %% [markdown]
# **Querying NCBI genome sequences**
#
# Here you can find Python scripts for querying NCBI genome promoter sequences.
#
# Questions and suggestions should be sent to abraao@neuro.ufrn.br
#
#
# ---------------------------------------------------------------------------------
#
#
# Author: Abraão LP Andrade

# %%
import pandas as pd
import numpy as np
import Bio as bio
import os

from Bio import SeqIO
from Bio.SeqRecord import SeqRecord

# %%
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("bio:", bio.__version__)
# Out:
# pandas: 1.0.5
# numpy: 1.17.5
# bio: 1.78

# %% [markdown]
# Chromossome sequences (GenBank sequence): https://www.ncbi.nlm.nih.gov/assembly/GCF_003957565.1/
#  - folder_path//chromossome_seq//files
#
#
# Gene coordinate tables (Download>Track Data): https://www.ncbi.nlm.nih.gov/genome/gdv/browser/genome/?id=GCF_003957565.1
#  - folder_path//gene_table//files

# %%
print("FOLDER PATHS ------------------------------------------------------")
folder_path = input("enter the general folder path:               ") # D:/TCC/DADOS/%NCBI genoma/bTaeGut1/
chromossome_seq_folder_name = input("enter the chromossome sequence folder name:  ") # chromossome_seq
gene_table_folder_name = input("enter the gene coordinate table folder name: ") # gene_table
destination_folder_name = input("enter the destination query folder name:     ") # promoter_seqs

print("\nPROMOTER LIMITS ---------------------------------------------------")
up_limit = int(input("enter the upstream limit:   "))
down_limit = int(input("enter the downstream limit: "))
# Out:
# FOLDER PATHS ------------------------------------------------------
# enter the general folder path:               D:/TCC/DADOS/%NCBI genoma/bTaeGut1/
# enter the chromossome sequence folder name:  chromossome_seq
# enter the gene coordinate table folder name: gene_table
# enter the destination query folder name:     promoter_seqs
#
# PROMOTER LIMITS ---------------------------------------------------
# enter the upstream limit:   -1000
# enter the downstream limit: +500

# %%
os.chdir(folder_path) # moving to the main directory
filename_chromseq_list = os.listdir(path = chromossome_seq_folder_name) # chromosome sequence file name list

filename_chromseq_list
# Out:
# ['chrom_10_seq.fasta',
#  'chrom_11_seq.fasta',
#  'chrom_12_seq.fasta',
#  'chrom_13_seq.fasta',
#  'chrom_14_seq.fasta',
#  'chrom_15_seq.fasta',
#  'chrom_16_seq.fasta',
#  'chrom_17_seq.fasta',
#  'chrom_18_seq.fasta',
#  'chrom_19_seq.fasta',
#  'chrom_1A_seq.fasta',
#  'chrom_1_seq.fasta',
#  'chrom_20_seq.fasta',
#  'chrom_21_seq.fasta',
#  'chrom_22_seq.fasta',
#  'chrom_23_seq.fasta',
#  'chrom_24_seq.fasta',
#  'chrom_25_seq.fasta',
#  'chrom_26_seq.fasta',
#  'chrom_27_seq.fasta',
#  'chrom_28_seq.fasta',
#  'chrom_29_seq.fasta',
#  'chrom_2_seq.fasta',
#  'chrom_30_seq.fasta',
#  'chrom_3_seq.fasta',
#  'chrom_4A_seq.fasta',
#  'chrom_4_seq.fasta',
#  'chrom_5_seq.fasta',
#  'chrom_6_seq.fasta',
#  'chrom_7_seq.fasta',
#  'chrom_8_seq.fasta',
#  'chrom_9_seq.fasta',
#  'chrom_mt_seq.fasta',
#  'chrom_NW_022045285_seq.fasta',
#  'chrom_NW_022045286_seq.fasta',
#  'chrom_NW_022045287_seq.fasta',
#  'chrom_NW_022045288_seq.fasta',
#  'chrom_NW_022045289_seq.fasta',
#  'chrom_NW_022045290_seq.fasta',
#  'chrom_NW_022045291_seq.fasta',
#  'chrom_NW_022045292_seq.fasta',
#  'chrom_NW_022045293_seq.fasta',
#  'chrom_NW_022045294_seq.fasta',
#  'chrom_NW_022045295_seq.fasta',
#  'chrom_NW_022045296_seq.fasta',
#  'chrom_NW_022045297_seq.fasta',
#  'chrom_NW_022045298_seq.fasta',
#  'chrom_NW_022045299_seq.fasta',
#  'chrom_NW_022045300_seq.fasta',
#  'chrom_NW_022045301_seq.fasta',
#  'chrom_NW_022045302_seq.fasta',
#  'chrom_NW_022045304_seq.fasta',
#  'chrom_NW_022045305_seq.fasta',
#  'chrom_NW_022045306_seq.fasta',
#  'chrom_NW_022045307_seq.fasta',
#  'chrom_NW_022045308_seq.fasta',
#  'chrom_NW_022045309_seq.fasta',
#  'chrom_NW_022045310_seq.fasta',
#  'chrom_NW_022045311_seq.fasta',
#  'chrom_NW_022045312_seq.fasta',
#  'chrom_NW_022045313_seq.fasta',
#  'chrom_NW_022045314_seq.fasta',
#  'chrom_NW_022045315_seq.fasta',
#  'chrom_NW_022045316_seq.fasta',
#  'chrom_NW_022045317_seq.fasta',
#  'chrom_NW_022045318_seq.fasta',
#  'chrom_NW_022045319_seq.fasta',
#  'chrom_NW_022045320_seq.fasta',
#  'chrom_NW_022045321_seq.fasta',
#  'chrom_NW_022045322_seq.fasta',
#  'chrom_NW_022045323_seq.fasta',
#  'chrom_NW_022045324_seq.fasta',
#  'chrom_NW_022045325_seq.fasta',
#  'chrom_NW_022045326_seq.fasta',
#  'chrom_NW_022045327_seq.fasta',
#  'chrom_NW_022045328_seq.fasta',
#  'chrom_NW_022045329_seq.fasta',
#  'chrom_NW_022045330_seq.fasta',
#  'chrom_NW_022045331_seq.fasta',
#  'chrom_NW_022045332_seq.fasta',
#  'chrom_NW_022045333_seq.fasta',
#  'chrom_NW_022045334_seq.fasta',
#  'chrom_NW_022045335_seq.fasta',
#  'chrom_NW_022045337_seq.fasta',
#  'chrom_NW_022045338_seq.fasta',
#  'chrom_NW_022045339_seq.fasta',
#  'chrom_NW_022045340_seq.fasta',
#  'chrom_NW_022045341_seq.fasta',
#  'chrom_NW_022045342_seq.fasta',
#  'chrom_NW_022045343_seq.fasta',
#  'chrom_NW_022045344_seq.fasta',
#  'chrom_NW_022045345_seq.fasta',
#  'chrom_NW_022045346_seq.fasta',
#  'chrom_NW_022045348_seq.fasta',
#  'chrom_NW_022045349_seq.fasta',
#  'chrom_NW_022045350_seq.fasta',
#  'chrom_NW_022045351_seq.fasta',
#  'chrom_NW_022045353_seq.fasta',
#  'chrom_NW_022045354_seq.fasta',
#  'chrom_NW_022045355_seq.fasta',
#  'chrom_NW_022045356_seq.fasta',
#  'chrom_NW_022045357_seq.fasta',
#  'chrom_NW_022045358_seq.fasta',
#  'chrom_NW_022045359_seq.fasta',
#  'chrom_NW_022045360_seq.fasta',
#  'chrom_NW_022045361_seq.fasta',
#  'chrom_NW_022045362_seq.fasta',
#  'chrom_NW_022045364_seq.fasta',
#  'chrom_NW_022045366_seq.fasta',
#  'chrom_NW_022045367_seq.fasta',
#  'chrom_NW_022045368_seq.fasta',
#  'chrom_NW_022045369_seq.fasta',
#  'chrom_NW_022045370_seq.fasta',
#  'chrom_NW_022045371_seq.fasta',
#  'chrom_NW_022045372_seq.fasta',
#  'chrom_NW_022045373_seq.fasta',
#  'chrom_NW_022045374_seq.fasta',
#  'chrom_NW_022045376_seq.fasta',
#  'chrom_NW_022045377_seq.fasta',
#  'chrom_NW_022045378_seq.fasta',
#  'chrom_NW_022045379_seq.fasta',
#  'chrom_NW_022045380_seq.fasta',
#  'chrom_NW_022045381_seq.fasta',
#  'chrom_NW_022045383_seq.fasta',
#  'chrom_Z_seq.fasta']

# %%
os.makedirs(destination_folder_name)
    
evaluating_results = {} 
for file_name in filename_chromseq_list:
    PROMOTER_SEQS = []
    
    CHROM_SEQ = list(SeqIO.parse(chromossome_seq_folder_name + "/" + file_name, "fasta"))
    REVERSE_CHROM_SEQ = CHROM_SEQ[0].reverse_complement()
    
    chrom_name = file_name[:-10]
    REFSEQ_CHROM = pd.read_csv(gene_table_folder_name + "/" + chrom_name + "_gene_table.CSV", skiprows = 1)
    print(chrom_name)
    
    
    for gene_idx in range(len(REFSEQ_CHROM)):
        
        
        # 1. SELECTING THE PROMOTER REGION (up/down) ---------------------------------------
        coord = np.array([REFSEQ_CHROM["Start"][gene_idx], REFSEQ_CHROM["Stop"][gene_idx]], dtype = int)

            # 1.1. checking the strand
        if REFSEQ_CHROM["Strand"][gene_idx] == "plus": 
            tss = coord[0]
            # 1.2. if the upstream region is smaller   
            # than 1000 select the existing region
            if tss>1000:
                gene_seq = CHROM_SEQ[0].seq[tss+up_limit-1:tss+down_limit-1]
            else: 
                gene_seq = CHROM_SEQ[0].seq[0:tss+down_limit-1]
        else:
            tss = len(CHROM_SEQ[0].seq)-coord[1]
            if tss>1000:
                gene_seq = REVERSE_CHROM_SEQ.seq[tss+up_limit:tss+down_limit]
            else:
                gene_seq = REVERSE_CHROM_SEQ.seq[0:tss+down_limit]
        # -------------------------------------------------------------------------------------
          
            
        # 2. WRITING THE FASTA DESCRIPTION ----------------------------------------------------
            # GeneID|GeneSymbol|Chromossome|Start|Stop|Strand|Accession 
        description = "{}|{}|{}|{}|{}|{}|{}".format(REFSEQ_CHROM["NCBI Gene ID"][gene_idx], REFSEQ_CHROM["Gene symbol"][gene_idx], 
                                                 chrom_name, coord[0], coord[1], REFSEQ_CHROM["Strand"][gene_idx],
                                                 REFSEQ_CHROM["Accession"][gene_idx])
        # ------------------------------------------------------------------------------------
        
        
        # 3. CREATING RECORDER AND ADDING TO A LIST ------------------------------------------
        new_record = SeqRecord(gene_seq, description, "", "")
